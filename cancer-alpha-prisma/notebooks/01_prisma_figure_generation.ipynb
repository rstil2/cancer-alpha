# %% [markdown]
# # PRISMA Figure Generation for Cancer AlphaThis notebook provides an interactive environment for generating the PRISMA figure based on the Cancer Alpha data preprocessing pipeline.## Overview- Load processed data from the Cancer Alpha project- Generate a PRISMA flow diagram- Visualize the data flow and sample distribution

# %%
import pandas as pdimport matplotlib.pyplot as pltfrom src.prisma_figure.renderer import generate_prisma_figure# Load processed datadata_path = '../models/'X_processed = pd.read_csv(data_path + 'X_processed.csv')y_processed = pd.read_csv(data_path + 'y_processed.csv')# Display the shape of the loaded dataprint(f"Loaded feature matrix shape: {X_processed.shape}")print(f"Loaded labels shape: {y_processed.shape}")# Generate PRISMA figureprisma_figure_path = '../models/prisma_figure.png'generate_prisma_figure(X_processed, y_processed, prisma_figure_path)# Display the generated PRISMA figureimg = plt.imread(prisma_figure_path)plt.imshow(img)plt.axis('off')plt.title('PRISMA Flow Diagram')plt.show()
